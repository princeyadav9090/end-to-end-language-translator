# %%
# !pip3 install indic-nlp-library
# Out:
# Collecting indic-nlp-library
#   Downloading indic_nlp_library-0.92-py3-none-any.whl.metadata (5.7 kB)
# Collecting sphinx-argparse (from indic-nlp-library)
#   Downloading sphinx_argparse-0.5.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (0.2.4)
# Collecting morfessor (from indic-nlp-library)
#   Downloading Morfessor-2.0.6-py3-none-any.whl.metadata (628 bytes)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from indic-nlp-library) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->indic-nlp-library) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->indic-nlp-library) (2025.2)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (8.2.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.11/dist-packages (from sphinx-argparse->indic-nlp-library) (0.21.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->indic-nlp-library) (1.17.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.19.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.32.4)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.1.0)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.11/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (25.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->indic-nlp-library) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->indic-nlp-library) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->indic-nlp-library) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx>=5.1.0->sphinx-argparse->indic-nlp-library) (2025.6.15)
# Downloading indic_nlp_library-0.92-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 1.7 MB/s eta 0:00:00
# Downloading Morfessor-2.0.6-py3-none-any.whl (35 kB)
# Downloading sphinx_argparse-0.5.2-py3-none-any.whl (12 kB)
# Installing collected packages: morfessor, sphinx-argparse, indic-nlp-library
# Successfully installed indic-nlp-library-0.92 morfessor-2.0.6 sphinx-argparse-0.5.2

# %%
import pandas as pd
import numpy as np
from transformers import AutoTokenizer
import torch
from indicnlp.tokenize import indic_tokenize
import torch.nn.functional as F

# %%
data = pd.read_csv("/kaggle/input/english-hindi-dataset/Sentence pairs in English-Hindi - 2025-02-11.tsv",
                  sep="\t",header=None,names=["SrcSentID","SrcSent","DstSentID","DstSent"])

# %%
data.head()
# Out:
#    SrcSentID                                  SrcSent  DstSentID  \
# 0       1282                       Muiriel is 20 now.     485968
# 1       1282                       Muiriel is 20 now.    2060319
# 2       1294  Education in this world disappoints me.     485564
# 3       1302                       That won't happen.    2060320
# 4       1308                              I miss you.    2060321
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
data.drop(labels=[data.columns[0],data.columns[2]],axis=1,inplace=True)

# %%
data.head()
# Out:
#                                    SrcSent  \
# 0                       Muiriel is 20 now.
# 1                       Muiriel is 20 now.
# 2  Education in this world disappoints me.
# 3                       That won't happen.
# 4                              I miss you.
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
src_sent_tokenizer = AutoTokenizer.from_pretrained("google-T5/T5-base")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
data["SrcSent"] = data["SrcSent"].apply(lambda x: src_sent_tokenizer.tokenize(x))

# %%
data.head()
# Out:
#                                              SrcSent  \
# 0                  [▁Mu, i, riel, ▁is, ▁20, ▁now, .]
# 1                  [▁Mu, i, riel, ▁is, ▁20, ▁now, .]
# 2  [▁Education, ▁in, ▁this, ▁world, ▁disappoint, ...
# 3                    [▁That, ▁won, ', t, ▁happen, .]
# 4                               [▁I, ▁miss, ▁you, .]
#
#                                        DstSent
# 0             म्यूरियल अब बीस साल की हो गई है।
# 1                   म्यूरियल अब बीस साल की है।
# 2  मैं इस दुनिया में शिक्षा पर बहुत निराश हूँ।
# 3                              वैसा नहीं होगा।
# 4                 मुझें तुम्हारी याद आ रही है।

# %%
data["DstSent"] = data["DstSent"].apply(lambda x: indic_tokenize.trivial_tokenize(x,lang="hi"))

# %%
data["SrcSent"] = data["SrcSent"].apply(src_sent_tokenizer.convert_tokens_to_ids)

# %%
Vs = src_sent_tokenizer.get_vocab()

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent
# 0        [म्यूरियल, अब, बीस, साल, की, हो, गई, है, ।]
# 1                [म्यूरियल, अब, बीस, साल, की, है, ।]
# 2  [मैं, इस, दुनिया, में, शिक्षा, पर, बहुत, निराश...
# 3                              [वैसा, नहीं, होगा, ।]
# 4              [मुझें, तुम्हारी, याद, आ, रही, है, ।]

# %%
hindi_vocab = set()

for tokenized_hindi_sent in data["DstSent"]:
    hindi_vocab.update(tokenized_hindi_sent)

# %%
Vd = dict()
for idx, token in enumerate(hindi_vocab):
    Vd[token] = idx + 3
Vd["<PAD>"] = 0
Vd["<SOS>"] = 1
Vd["<EOS>"] = 2

# %%
hindi_idx2vocab = dict(zip(Vd.values(),Vd.keys()))

# %%
def convert_hindi_tokens_to_ids(hindi_sent):
    return [Vd[token] for token in hindi_sent]

# %%
data["DstSent"] = data["DstSent"].apply(lambda x: convert_hindi_tokens_to_ids(x))

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent
# 0  [605, 4005, 5426, 2264, 1818, 5846, 2492, 3829...
# 1          [605, 4005, 5426, 2264, 1818, 3829, 6583]
# 2  [1829, 2400, 1153, 4299, 838, 1381, 6195, 422,...
# 3                            [3308, 745, 2100, 6583]
# 4           [4312, 4144, 3151, 6080, 34, 3829, 6583]

# %%
def insert_sos_token_id(hindi_sent_token_ids):
    return [1] + hindi_sent_token_ids

# %%
data["DstSentInput"] = data["DstSent"].apply(lambda x: insert_sos_token_id(x))

# %%
def insert_eos_token_id(hindi_sent_token_ids):
    return hindi_sent_token_ids + [2]

# %%
data["DstSentLabel"] = data["DstSent"].apply(lambda x: insert_eos_token_id(x))

# %%
data.head()
# Out:
#                                  SrcSent  \
# 0     [4159, 23, 14018, 19, 460, 230, 5]
# 1     [4159, 23, 14018, 19, 460, 230, 5]
# 2  [2855, 16, 48, 296, 26963, 7, 140, 5]
# 3            [466, 751, 31, 17, 1837, 5]
# 4                      [27, 3041, 25, 5]
#
#                                              DstSent  \
# 0  [605, 4005, 5426, 2264, 1818, 5846, 2492, 3829...
# 1          [605, 4005, 5426, 2264, 1818, 3829, 6583]
# 2  [1829, 2400, 1153, 4299, 838, 1381, 6195, 422,...
# 3                            [3308, 745, 2100, 6583]
# 4           [4312, 4144, 3151, 6080, 34, 3829, 6583]
#
#                                         DstSentInput  \
# 0  [1, 605, 4005, 5426, 2264, 1818, 5846, 2492, 3...
# 1       [1, 605, 4005, 5426, 2264, 1818, 3829, 6583]
# 2  [1, 1829, 2400, 1153, 4299, 838, 1381, 6195, 4...
# 3                         [1, 3308, 745, 2100, 6583]
# 4        [1, 4312, 4144, 3151, 6080, 34, 3829, 6583]
#
#                                         DstSentLabel
# 0  [605, 4005, 5426, 2264, 1818, 5846, 2492, 3829...
# 1       [605, 4005, 5426, 2264, 1818, 3829, 6583, 2]
# 2  [1829, 2400, 1153, 4299, 838, 1381, 6195, 422,...
# 3                         [3308, 745, 2100, 6583, 2]
# 4        [4312, 4144, 3151, 6080, 34, 3829, 6583, 2]

# %%
data.drop(labels=[data.columns[1]],axis=1,inplace=True)

# %%
X = list(data["SrcSent"])
Y_input = list(data["DstSentInput"])
Y_label = list(data["DstSentLabel"])

# %%
X_tensor = [torch.tensor(tokenized_eng_sent_ids) for tokenized_eng_sent_ids in X]
Y_input_tensor = [torch.tensor(tokenized_hin_sent_ids) for tokenized_hin_sent_ids in Y_input]
Y_label_tensor = [torch.tensor(tokenized_hin_sent_ids) for tokenized_hin_sent_ids in Y_label]

# %%
X_padded = torch.nn.utils.rnn.pad_sequence(X_tensor,batch_first=True)
Y_padded_input = torch.nn.utils.rnn.pad_sequence(Y_input_tensor,batch_first=True)
Y_padded_label = torch.nn.utils.rnn.pad_sequence(Y_label_tensor,batch_first=True)

# %%
Ns = X_padded.shape[1]
Nd = Y_padded_label.shape[1]

# %%
class Encoder(torch.nn.Module):

    def __init__(self,src_lang_vocab_size,word_embedding_dim):
        super(Encoder,self).__init__()
        self.first_embedding_layer = torch.nn.Embedding(num_embeddings=src_lang_vocab_size,
                                                       embedding_dim=word_embedding_dim)
        self.second_lstm_layer = torch.nn.LSTM(input_size=word_embedding_dim,
                                               hidden_size=word_embedding_dim,
                                              batch_first=True)

    def forward(self,X_padded_mini_batch):

        first_embedding_layer_out = self.first_embedding_layer(X_padded_mini_batch)
        encoder_output, (final_encoder_output,final_cell_state) = self.second_lstm_layer(first_embedding_layer_out)

        return encoder_output, (final_encoder_output,final_cell_state)

# %%
class Decoder(torch.nn.Module):

    def __init__(self,dst_lang_vocab_size,word_embedding_dim):
        super(Decoder,self).__init__()

        self.first_embedding_layer = torch.nn.Embedding(num_embeddings=dst_lang_vocab_size,
                                                       embedding_dim=word_embedding_dim)
        self.second_lstm_layer = torch.nn.LSTM(input_size=word_embedding_dim,
                                               hidden_size=word_embedding_dim,
                                              batch_first=True)
        self.prediction_layer = torch.nn.Linear(in_features=word_embedding_dim,out_features=dst_lang_vocab_size)
        #self.prediction_layer_activation = torch.nn.Softmax(dim=2)

    def forward(self,Y_padded_input_mini_batch,final_encoder_output,final_cell_state):

        first_embedding_layer_out = self.first_embedding_layer(Y_padded_input_mini_batch)
        decoder_lstm_layer_out, (final_decoder_lstm_layer_out, final_cell_state) = self.second_lstm_layer(first_embedding_layer_out,
                                                                                                         (final_encoder_output,
                                                                                                          final_cell_state))
        prediction = self.prediction_layer(decoder_lstm_layer_out)
        
        return prediction, (final_decoder_lstm_layer_out, final_cell_state)

# %%
class Seq2SeqEncDec(torch.nn.Module):

    def __init__(self,src_lang_vocab_size,dst_lang_vocab_size,word_embedding_dim):
        super(Seq2SeqEncDec,self).__init__()

        self.encoder = Encoder(src_lang_vocab_size,word_embedding_dim)
        self.decoder = Decoder(dst_lang_vocab_size,word_embedding_dim)

    def forward(self,X_padded_mini_batch,Y_padded_input_mini_batch):

        encoder_output, (final_encoder_output,final_cell_state) = self.encoder(X_padded_mini_batch)
        y_hat_mini_batch = self.decoder(Y_padded_input_mini_batch,
                                        final_encoder_output,final_cell_state)

        return y_hat_mini_batch

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print(device)
# Out:
# cuda

# %%
X_padded_train = X_padded[0:13000]
Y_padded_input_train = Y_padded_input[0:13000]
Y_padded_label_train = Y_padded_label[0:13000]

X_padded_test = X_padded[13000:]
Y_padded_input_test = Y_padded_input[13000:]
Y_padded_label_test = Y_padded_label[13000:]

# %%
network = Seq2SeqEncDec(len(Vs),len(Vd),128).to(device)

# %%
loss_fn = torch.nn.CrossEntropyLoss(ignore_index=0)
optimizer = torch.optim.Adam(network.parameters())
num_epochs = 250
mb_size = 65

for epoch in range(num_epochs):
    for i in range(X_padded_train.shape[0]//mb_size):

        X_train_mb = X_padded_train[i*mb_size:(i+1)*mb_size]
        Y_input_mb = Y_padded_input_train[i*mb_size:(i+1)*mb_size]
        Y_label_mb = Y_padded_label_train[i*mb_size:(i+1)*mb_size]
        Y_label_mb = Y_label_mb.reshape(Y_label_mb.shape[0]*Y_label_mb.shape[1],)
        
        X_train_mb, Y_input_mb, Y_label_mb = X_train_mb.to(device), Y_input_mb.to(device), Y_label_mb.to(device)

        y_hat_train_mb = network(X_train_mb,Y_input_mb)
        y_hat_train_mb = y_hat_train_mb[0]
        y_hat_train_mb = y_hat_train_mb.reshape(y_hat_train_mb.shape[0]*y_hat_train_mb.shape[1],
                                                y_hat_train_mb.shape[2])

        loss_fn_value = loss_fn(y_hat_train_mb,Y_label_mb)

        loss_fn_value.backward()
        #torch.nn.utils.clip_grad_norm_(network.parameters(),max_norm=1.0)
        optimizer.step()
        optimizer.zero_grad()

        print("Epoch # {}, Time Step # {}, Loss Value = {}".format(epoch,i,loss_fn_value))
# Out:
# Epoch # 0, Time Step # 0, Loss Value = 8.871939659118652
# Epoch # 0, Time Step # 1, Loss Value = 8.851677894592285
# Epoch # 0, Time Step # 2, Loss Value = 8.817825317382812
# Epoch # 0, Time Step # 3, Loss Value = 8.791372299194336
# Epoch # 0, Time Step # 4, Loss Value = 8.778950691223145
# Epoch # 0, Time Step # 5, Loss Value = 8.725166320800781
# Epoch # 0, Time Step # 6, Loss Value = 8.70742416381836
# Epoch # 0, Time Step # 7, Loss Value = 8.655342102050781
# Epoch # 0, Time Step # 8, Loss Value = 8.629264831542969
# Epoch # 0, Time Step # 9, Loss Value = 8.568235397338867
# Epoch # 0, Time Step # 10, Loss Value = 8.487862586975098
# Epoch # 0, Time Step # 11, Loss Value = 8.454503059387207
# Epoch # 0, Time Step # 12, Loss Value = 8.244486808776855
# Epoch # 0, Time Step # 13, Loss Value = 8.263328552246094
# Epoch # 0, Time Step # 14, Loss Value = 8.079233169555664
# Epoch # 0, Time Step # 15, Loss Value = 7.983452796936035
# Epoch # 0, Time Step # 16, Loss Value = 7.804422378540039
# Epoch # 0, Time Step # 17, Loss Value = 7.63082218170166
# Epoch # 0, Time Step # 18, Loss Value = 7.398663520812988
# Epoch # 0, Time Step # 19, Loss Value = 7.376236438751221
# Epoch # 0, Time Step # 20, Loss Value = 7.225512981414795
# Epoch # 0, Time Step # 21, Loss Value = 6.976459980010986
# Epoch # 0, Time Step # 22, Loss Value = 6.766346454620361
# Epoch # 0, Time Step # 23, Loss Value = 6.696259498596191
# Epoch # 0, Time Step # 24, Loss Value = 6.733882427215576
# Epoch # 0, Time Step # 25, Loss Value = 6.566625118255615
# Epoch # 0, Time Step # 26, Loss Value = 6.316764831542969
# Epoch # 0, Time Step # 27, Loss Value = 6.294998645782471
# Epoch # 0, Time Step # 28, Loss Value = 6.123376846313477
# Epoch # 0, Time Step # 29, Loss Value = 5.995102405548096
# Epoch # 0, Time Step # 30, Loss Value = 5.847887992858887
# Epoch # 0, Time Step # 31, Loss Value = 5.7622199058532715
# Epoch # 0, Time Step # 32, Loss Value = 5.651973247528076
# Epoch # 0, Time Step # 33, Loss Value = 5.636919021606445
# Epoch # 0, Time Step # 34, Loss Value = 5.946171283721924
# Epoch # 0, Time Step # 35, Loss Value = 6.132172584533691
# Epoch # 0, Time Step # 36, Loss Value = 6.122729778289795
# Epoch # 0, Time Step # 37, Loss Value = 5.9219069480896
# Epoch # 0, Time Step # 38, Loss Value = 6.000772953033447
# Epoch # 0, Time Step # 39, Loss Value = 5.953256607055664
# Epoch # 0, Time Step # 40, Loss Value = 5.658834457397461
# Epoch # 0, Time Step # 41, Loss Value = 5.8954386711120605
# Epoch # 0, Time Step # 42, Loss Value = 5.477804660797119
# Epoch # 0, Time Step # 43, Loss Value = 5.760390758514404
# Epoch # 0, Time Step # 44, Loss Value = 5.504307270050049
# Epoch # 0, Time Step # 45, Loss Value = 5.534276485443115
# Epoch # 0, Time Step # 46, Loss Value = 5.809535980224609
# Epoch # 0, Time Step # 47, Loss Value = 5.444003582000732
# Epoch # 0, Time Step # 48, Loss Value = 5.671518325805664
# Epoch # 0, Time Step # 49, Loss Value = 5.463262557983398
# Epoch # 0, Time Step # 50, Loss Value = 5.474077224731445
# Epoch # 0, Time Step # 51, Loss Value = 5.623183727264404
# Epoch # 0, Time Step # 52, Loss Value = 5.788994312286377
# Epoch # 0, Time Step # 53, Loss Value = 5.6516289710998535
# Epoch # 0, Time Step # 54, Loss Value = 5.829774856567383
# Epoch # 0, Time Step # 55, Loss Value = 6.000095844268799
# Epoch # 0, Time Step # 56, Loss Value = 5.461343765258789
# Epoch # 0, Time Step # 57, Loss Value = 5.64763879776001
# Epoch # 0, Time Step # 58, Loss Value = 5.662973880767822
# Epoch # 0, Time Step # 59, Loss Value = 5.139511585235596
# Epoch # 0, Time Step # 60, Loss Value = 5.238034248352051
# Epoch # 0, Time Step # 61, Loss Value = 5.313305854797363
# Epoch # 0, Time Step # 62, Loss Value = 5.819146633148193
# Epoch # 0, Time Step # 63, Loss Value = 6.021533489227295
# Epoch # 0, Time Step # 64, Loss Value = 5.505623817443848
# Epoch # 0, Time Step # 65, Loss Value = 5.6831254959106445
# Epoch # 0, Time Step # 66, Loss Value = 6.113168239593506
# Epoch # 0, Time Step # 67, Loss Value = 6.259432792663574
# Epoch # 0, Time Step # 68, Loss Value = 5.665597438812256
# Epoch # 0, Time Step # 69, Loss Value = 6.241236209869385
# Epoch # 0, Time Step # 70, Loss Value = 5.663954257965088
# Epoch # 0, Time Step # 71, Loss Value = 5.792682647705078
# Epoch # 0, Time Step # 72, Loss Value = 5.610371112823486
# Epoch # 0, Time Step # 73, Loss Value = 5.935143947601318
# Epoch # 0, Time Step # 74, Loss Value = 5.682465076446533
# Epoch # 0, Time Step # 75, Loss Value = 5.631262302398682
# Epoch # 0, Time Step # 76, Loss Value = 5.795347690582275
# Epoch # 0, Time Step # 77, Loss Value = 5.644519805908203
# Epoch # 0, Time Step # 78, Loss Value = 5.349342346191406
# Epoch # 0, Time Step # 79, Loss Value = 5.746595859527588
# Epoch # 0, Time Step # 80, Loss Value = 4.989631175994873
# Epoch # 0, Time Step # 81, Loss Value = 5.387358665466309
# Epoch # 0, Time Step # 82, Loss Value = 4.983870029449463
# Epoch # 0, Time Step # 83, Loss Value = 5.227756023406982
# Epoch # 0, Time Step # 84, Loss Value = 5.113361835479736
# Epoch # 0, Time Step # 85, Loss Value = 4.903682708740234
# Epoch # 0, Time Step # 86, Loss Value = 4.735799312591553
# Epoch # 0, Time Step # 87, Loss Value = 4.7825727462768555
# Epoch # 0, Time Step # 88, Loss Value = 5.015143871307373
# Epoch # 0, Time Step # 89, Loss Value = 4.921215057373047
# Epoch # 0, Time Step # 90, Loss Value = 4.308094501495361
# Epoch # 0, Time Step # 91, Loss Value = 4.6434221267700195
# Epoch # 0, Time Step # 92, Loss Value = 5.455051422119141
# Epoch # 0, Time Step # 93, Loss Value = 4.424562454223633
# Epoch # 0, Time Step # 94, Loss Value = 5.467261791229248
# Epoch # 0, Time Step # 95, Loss Value = 6.5659966468811035
# Epoch # 0, Time Step # 96, Loss Value = 6.6490254402160645
# Epoch # 0, Time Step # 97, Loss Value = 5.467550754547119
# Epoch # 0, Time Step # 98, Loss Value = 4.846619129180908
# Epoch # 0, Time Step # 99, Loss Value = 5.039676189422607
# Epoch # 0, Time Step # 100, Loss Value = 5.1441521644592285
# Epoch # 0, Time Step # 101, Loss Value = 4.433124542236328
# Epoch # 0, Time Step # 102, Loss Value = 4.324925899505615
# Epoch # 0, Time Step # 103, Loss Value = 4.803575038909912
# Epoch # 0, Time Step # 104, Loss Value = 4.8340044021606445
# Epoch # 0, Time Step # 105, Loss Value = 4.715750217437744
# Epoch # 0, Time Step # 106, Loss Value = 4.6849894523620605
# Epoch # 0, Time Step # 107, Loss Value = 4.359373092651367
# Epoch # 0, Time Step # 108, Loss Value = 4.582941055297852
# Epoch # 0, Time Step # 109, Loss Value = 4.335540294647217
# Epoch # 0, Time Step # 110, Loss Value = 4.548211574554443
# Epoch # 0, Time Step # 111, Loss Value = 5.667299747467041
# Epoch # 0, Time Step # 112, Loss Value = 6.1218156814575195
# Epoch # 0, Time Step # 113, Loss Value = 5.534987926483154
# Epoch # 0, Time Step # 114, Loss Value = 5.047293663024902
# Epoch # 0, Time Step # 115, Loss Value = 5.016932964324951
# Epoch # 0, Time Step # 116, Loss Value = 5.245401382446289
# Epoch # 0, Time Step # 117, Loss Value = 5.034580707550049
# Epoch # 0, Time Step # 118, Loss Value = 4.733731746673584
# Epoch # 0, Time Step # 119, Loss Value = 5.253945350646973
# Epoch # 0, Time Step # 120, Loss Value = 5.6109795570373535
# Epoch # 0, Time Step # 121, Loss Value = 4.561617851257324
# Epoch # 0, Time Step # 122, Loss Value = 4.841485977172852
# Epoch # 0, Time Step # 123, Loss Value = 4.79253625869751
# Epoch # 0, Time Step # 124, Loss Value = 4.659894943237305
# Epoch # 0, Time Step # 125, Loss Value = 4.837666034698486
# Epoch # 0, Time Step # 126, Loss Value = 4.783287525177002
# Epoch # 0, Time Step # 127, Loss Value = 4.8859992027282715
# Epoch # 0, Time Step # 128, Loss Value = 5.388299465179443
# Epoch # 0, Time Step # 129, Loss Value = 5.533581733703613
# Epoch # 0, Time Step # 130, Loss Value = 5.4996256828308105
# Epoch # 0, Time Step # 131, Loss Value = 4.928715229034424
# Epoch # 0, Time Step # 132, Loss Value = 4.5443315505981445
# Epoch # 0, Time Step # 133, Loss Value = 4.310049057006836
# Epoch # 0, Time Step # 134, Loss Value = 4.852540969848633
# Epoch # 0, Time Step # 135, Loss Value = 4.593973159790039
# Epoch # 0, Time Step # 136, Loss Value = 4.764802932739258
# Epoch # 0, Time Step # 137, Loss Value = 4.9670891761779785
# Epoch # 0, Time Step # 138, Loss Value = 4.547621726989746
# Epoch # 0, Time Step # 139, Loss Value = 5.152696132659912
# Epoch # 0, Time Step # 140, Loss Value = 4.861682415008545
# Epoch # 0, Time Step # 141, Loss Value = 4.615445613861084
# Epoch # 0, Time Step # 142, Loss Value = 4.439751148223877
# Epoch # 0, Time Step # 143, Loss Value = 4.7477707862854
# Epoch # 0, Time Step # 144, Loss Value = 4.410272598266602
# Epoch # 0, Time Step # 145, Loss Value = 4.395950794219971
# Epoch # 0, Time Step # 146, Loss Value = 4.2689008712768555
# Epoch # 0, Time Step # 147, Loss Value = 4.964818954467773
# Epoch # 0, Time Step # 148, Loss Value = 4.643756866455078
# Epoch # 0, Time Step # 149, Loss Value = 4.836050987243652
# Epoch # 0, Time Step # 150, Loss Value = 4.6029276847839355
# Epoch # 0, Time Step # 151, Loss Value = 4.767168998718262
# Epoch # 0, Time Step # 152, Loss Value = 4.915318965911865
# Epoch # 0, Time Step # 153, Loss Value = 4.583682060241699
# Epoch # 0, Time Step # 154, Loss Value = 4.467129230499268
# Epoch # 0, Time Step # 155, Loss Value = 4.711654186248779
# Epoch # 0, Time Step # 156, Loss Value = 4.735026836395264
# Epoch # 0, Time Step # 157, Loss Value = 4.671457767486572
# Epoch # 0, Time Step # 158, Loss Value = 4.661548614501953
# Epoch # 0, Time Step # 159, Loss Value = 5.625865936279297
# Epoch # 0, Time Step # 160, Loss Value = 5.370312690734863
# Epoch # 0, Time Step # 161, Loss Value = 5.7486958503723145
# Epoch # 0, Time Step # 162, Loss Value = 5.665292263031006
# Epoch # 0, Time Step # 163, Loss Value = 5.148022174835205
# Epoch # 0, Time Step # 164, Loss Value = 5.159186363220215
# Epoch # 0, Time Step # 165, Loss Value = 4.937761306762695
# Epoch # 0, Time Step # 166, Loss Value = 4.853024005889893
# Epoch # 0, Time Step # 167, Loss Value = 5.314911842346191
# Epoch # 0, Time Step # 168, Loss Value = 4.97688627243042
# Epoch # 0, Time Step # 169, Loss Value = 5.108756065368652
# Epoch # 0, Time Step # 170, Loss Value = 5.167129039764404
# Epoch # 0, Time Step # 171, Loss Value = 5.275060176849365
# Epoch # 0, Time Step # 172, Loss Value = 5.600890636444092
# Epoch # 0, Time Step # 173, Loss Value = 5.301775932312012
# Epoch # 0, Time Step # 174, Loss Value = 5.422108173370361
# Epoch # 0, Time Step # 175, Loss Value = 4.906058311462402
# Epoch # 0, Time Step # 176, Loss Value = 4.7421464920043945
# Epoch # 0, Time Step # 177, Loss Value = 4.802586078643799
# Epoch # 0, Time Step # 178, Loss Value = 5.130762100219727
# Epoch # 0, Time Step # 179, Loss Value = 4.914809703826904
# Epoch # 0, Time Step # 180, Loss Value = 5.246866703033447
# Epoch # 0, Time Step # 181, Loss Value = 4.901339530944824
# Epoch # 0, Time Step # 182, Loss Value = 4.6742329597473145
# Epoch # 0, Time Step # 183, Loss Value = 4.7356791496276855
# Epoch # 0, Time Step # 184, Loss Value = 4.813690662384033
# Epoch # 0, Time Step # 185, Loss Value = 4.786442756652832
# Epoch # 0, Time Step # 186, Loss Value = 4.902353286743164
# Epoch # 0, Time Step # 187, Loss Value = 5.859708309173584
# Epoch # 0, Time Step # 188, Loss Value = 4.765212535858154
# Epoch # 0, Time Step # 189, Loss Value = 4.812623023986816
# Epoch # 0, Time Step # 190, Loss Value = 4.7808427810668945
# Epoch # 0, Time Step # 191, Loss Value = 4.758016109466553
# Epoch # 0, Time Step # 192, Loss Value = 4.928445339202881
# Epoch # 0, Time Step # 193, Loss Value = 4.527297496795654
# Epoch # 0, Time Step # 194, Loss Value = 4.837860584259033
# Epoch # 0, Time Step # 195, Loss Value = 5.024633407592773
# Epoch # 0, Time Step # 196, Loss Value = 5.185669422149658
# Epoch # 0, Time Step # 197, Loss Value = 4.932154655456543
# Epoch # 0, Time Step # 198, Loss Value = 4.859951972961426
# Epoch # 0, Time Step # 199, Loss Value = 4.934720993041992
# Epoch # 1, Time Step # 0, Loss Value = 4.758530616760254
# Epoch # 1, Time Step # 1, Loss Value = 5.137645721435547
# Epoch # 1, Time Step # 2, Loss Value = 5.081514835357666
# Epoch # 1, Time Step # 3, Loss Value = 5.504093647003174
# Epoch # 1, Time Step # 4, Loss Value = 5.5735344886779785
# Epoch # 1, Time Step # 5, Loss Value = 5.230416774749756
# Epoch # 1, Time Step # 6, Loss Value = 5.435971260070801
# Epoch # 1, Time Step # 7, Loss Value = 5.366983890533447
# Epoch # 1, Time Step # 8, Loss Value = 5.507161617279053
# Epoch # 1, Time Step # 9, Loss Value = 5.517531394958496
# Epoch # 1, Time Step # 10, Loss Value = 5.149426460266113
# Epoch # 1, Time Step # 11, Loss Value = 5.438708782196045
# Epoch # 1, Time Step # 12, Loss Value = 5.057509899139404
# Epoch # 1, Time Step # 13, Loss Value = 5.551969528198242
# Epoch # 1, Time Step # 14, Loss Value = 5.396421432495117
# Epoch # 1, Time Step # 15, Loss Value = 5.4053239822387695
# Epoch # 1, Time Step # 16, Loss Value = 5.141203880310059
# Epoch # 1, Time Step # 17, Loss Value = 5.301487922668457
# Epoch # 1, Time Step # 18, Loss Value = 5.068741321563721
# Epoch # 1, Time Step # 19, Loss Value = 5.371359348297119
# Epoch # 1, Time Step # 20, Loss Value = 5.253625392913818
# Epoch # 1, Time Step # 21, Loss Value = 5.055222511291504
# Epoch # 1, Time Step # 22, Loss Value = 4.866927623748779
# Epoch # 1, Time Step # 23, Loss Value = 5.182703971862793
# Epoch # 1, Time Step # 24, Loss Value = 5.490145206451416
# Epoch # 1, Time Step # 25, Loss Value = 5.239875316619873
# Epoch # 1, Time Step # 26, Loss Value = 5.165574550628662
# Epoch # 1, Time Step # 27, Loss Value = 5.289041519165039
# Epoch # 1, Time Step # 28, Loss Value = 5.085552215576172
# Epoch # 1, Time Step # 29, Loss Value = 5.063201427459717
# Epoch # 1, Time Step # 30, Loss Value = 4.931064128875732
# Epoch # 1, Time Step # 31, Loss Value = 4.928595542907715
# Epoch # 1, Time Step # 32, Loss Value = 4.859562397003174
# Epoch # 1, Time Step # 33, Loss Value = 4.959085464477539
# Epoch # 1, Time Step # 34, Loss Value = 5.2346696853637695
# Epoch # 1, Time Step # 35, Loss Value = 5.436201095581055
# Epoch # 1, Time Step # 36, Loss Value = 5.488876819610596
# Epoch # 1, Time Step # 37, Loss Value = 5.373266696929932
# Epoch # 1, Time Step # 38, Loss Value = 5.312561511993408
# Epoch # 1, Time Step # 39, Loss Value = 5.368203163146973
# Epoch # 1, Time Step # 40, Loss Value = 5.120887279510498
# Epoch # 1, Time Step # 41, Loss Value = 5.241195201873779
# Epoch # 1, Time Step # 42, Loss Value = 4.882113456726074
# Epoch # 1, Time Step # 43, Loss Value = 5.142388820648193
# Epoch # 1, Time Step # 44, Loss Value = 4.906663417816162
# Epoch # 1, Time Step # 45, Loss Value = 4.963955879211426
# Epoch # 1, Time Step # 46, Loss Value = 5.214109897613525
# Epoch # 1, Time Step # 47, Loss Value = 4.847959518432617
# Epoch # 1, Time Step # 48, Loss Value = 5.096227645874023
# Epoch # 1, Time Step # 49, Loss Value = 4.959402084350586
# Epoch # 1, Time Step # 50, Loss Value = 4.890517234802246
# Epoch # 1, Time Step # 51, Loss Value = 5.069355010986328
# Epoch # 1, Time Step # 52, Loss Value = 5.264683246612549
# Epoch # 1, Time Step # 53, Loss Value = 5.074655055999756
# Epoch # 1, Time Step # 54, Loss Value = 5.310878276824951
# Epoch # 1, Time Step # 55, Loss Value = 5.30238676071167
# Epoch # 1, Time Step # 56, Loss Value = 4.8737263679504395
# Epoch # 1, Time Step # 57, Loss Value = 5.088948726654053
# Epoch # 1, Time Step # 58, Loss Value = 5.068146228790283
# Epoch # 1, Time Step # 59, Loss Value = 4.578230381011963
# Epoch # 1, Time Step # 60, Loss Value = 4.644876480102539
# Epoch # 1, Time Step # 61, Loss Value = 4.770785331726074
# Epoch # 1, Time Step # 62, Loss Value = 5.260593891143799
# Epoch # 1, Time Step # 63, Loss Value = 5.4446611404418945
# Epoch # 1, Time Step # 64, Loss Value = 4.892179489135742
# Epoch # 1, Time Step # 65, Loss Value = 5.137670516967773
# Epoch # 1, Time Step # 66, Loss Value = 5.396004676818848
# Epoch # 1, Time Step # 67, Loss Value = 5.644869804382324
# Epoch # 1, Time Step # 68, Loss Value = 5.0933613777160645
# Epoch # 1, Time Step # 69, Loss Value = 5.689322471618652
# Epoch # 1, Time Step # 70, Loss Value = 5.103486061096191
# Epoch # 1, Time Step # 71, Loss Value = 5.0664238929748535
# Epoch # 1, Time Step # 72, Loss Value = 4.884041786193848
# Epoch # 1, Time Step # 73, Loss Value = 5.361464977264404
# Epoch # 1, Time Step # 74, Loss Value = 5.191708087921143
# Epoch # 1, Time Step # 75, Loss Value = 5.116589069366455
# Epoch # 1, Time Step # 76, Loss Value = 5.219094276428223
# Epoch # 1, Time Step # 77, Loss Value = 5.1116228103637695
# Epoch # 1, Time Step # 78, Loss Value = 4.7173871994018555
# Epoch # 1, Time Step # 79, Loss Value = 5.1569414138793945
# Epoch # 1, Time Step # 80, Loss Value = 4.467090129852295
# Epoch # 1, Time Step # 81, Loss Value = 4.896745681762695
# Epoch # 1, Time Step # 82, Loss Value = 4.5190863609313965
# Epoch # 1, Time Step # 83, Loss Value = 4.760900497436523
# Epoch # 1, Time Step # 84, Loss Value = 4.527379035949707
# Epoch # 1, Time Step # 85, Loss Value = 4.502082347869873
# Epoch # 1, Time Step # 86, Loss Value = 4.201968669891357
# Epoch # 1, Time Step # 87, Loss Value = 4.3297858238220215
# Epoch # 1, Time Step # 88, Loss Value = 4.551631927490234
# Epoch # 1, Time Step # 89, Loss Value = 4.410562515258789
# Epoch # 1, Time Step # 90, Loss Value = 3.7603907585144043
# Epoch # 1, Time Step # 91, Loss Value = 4.170736789703369
# Epoch # 1, Time Step # 92, Loss Value = 5.079761028289795
# Epoch # 1, Time Step # 93, Loss Value = 3.996769428253174
# Epoch # 1, Time Step # 94, Loss Value = 5.073037624359131
# Epoch # 1, Time Step # 95, Loss Value = 6.250614166259766
# Epoch # 1, Time Step # 96, Loss Value = 6.402178764343262
# Epoch # 1, Time Step # 97, Loss Value = 5.0536603927612305
# Epoch # 1, Time Step # 98, Loss Value = 4.403834819793701
# Epoch # 1, Time Step # 99, Loss Value = 4.584463119506836
# Epoch # 1, Time Step # 100, Loss Value = 4.764007568359375
# Epoch # 1, Time Step # 101, Loss Value = 4.025385856628418
# Epoch # 1, Time Step # 102, Loss Value = 3.9087884426116943
# Epoch # 1, Time Step # 103, Loss Value = 4.463954925537109
# Epoch # 1, Time Step # 104, Loss Value = 4.392326831817627
# Epoch # 1, Time Step # 105, Loss Value = 4.353802680969238
# Epoch # 1, Time Step # 106, Loss Value = 4.30854606628418
# Epoch # 1, Time Step # 107, Loss Value = 3.970515012741089
# Epoch # 1, Time Step # 108, Loss Value = 4.231748104095459
# Epoch # 1, Time Step # 109, Loss Value = 3.992380380630493
# Epoch # 1, Time Step # 110, Loss Value = 4.155205726623535
# Epoch # 1, Time Step # 111, Loss Value = 5.281284809112549
# Epoch # 1, Time Step # 112, Loss Value = 5.657352924346924
# Epoch # 1, Time Step # 113, Loss Value = 5.1325459480285645
# Epoch # 1, Time Step # 114, Loss Value = 4.638448238372803
# Epoch # 1, Time Step # 115, Loss Value = 4.612231254577637
# Epoch # 1, Time Step # 116, Loss Value = 4.802265644073486
# Epoch # 1, Time Step # 117, Loss Value = 4.5863871574401855
# Epoch # 1, Time Step # 118, Loss Value = 4.360826015472412
# Epoch # 1, Time Step # 119, Loss Value = 4.788165092468262
# Epoch # 1, Time Step # 120, Loss Value = 5.235960006713867
# Epoch # 1, Time Step # 121, Loss Value = 4.170621395111084
# Epoch # 1, Time Step # 122, Loss Value = 4.468870639801025
# Epoch # 1, Time Step # 123, Loss Value = 4.462972164154053
# Epoch # 1, Time Step # 124, Loss Value = 4.307528018951416
# Epoch # 1, Time Step # 125, Loss Value = 4.451361656188965
# Epoch # 1, Time Step # 126, Loss Value = 4.386812686920166
# Epoch # 1, Time Step # 127, Loss Value = 4.441499710083008
# Epoch # 1, Time Step # 128, Loss Value = 4.998096466064453
# Epoch # 1, Time Step # 129, Loss Value = 5.179679870605469
# Epoch # 1, Time Step # 130, Loss Value = 5.146942615509033
# Epoch # 1, Time Step # 131, Loss Value = 4.555392265319824
# Epoch # 1, Time Step # 132, Loss Value = 4.193166255950928
# Epoch # 1, Time Step # 133, Loss Value = 3.9821696281433105
# Epoch # 1, Time Step # 134, Loss Value = 4.480300426483154
# Epoch # 1, Time Step # 135, Loss Value = 4.207034111022949
# Epoch # 1, Time Step # 136, Loss Value = 4.464327812194824
# Epoch # 1, Time Step # 137, Loss Value = 4.542842864990234
# Epoch # 1, Time Step # 138, Loss Value = 4.165421009063721
# Epoch # 1, Time Step # 139, Loss Value = 4.755399227142334
# Epoch # 1, Time Step # 140, Loss Value = 4.528295516967773
# Epoch # 1, Time Step # 141, Loss Value = 4.221978664398193
# Epoch # 1, Time Step # 142, Loss Value = 4.05967903137207
# Epoch # 1, Time Step # 143, Loss Value = 4.4265947341918945
# Epoch # 1, Time Step # 144, Loss Value = 4.088412761688232
# Epoch # 1, Time Step # 145, Loss Value = 4.011188983917236
# Epoch # 1, Time Step # 146, Loss Value = 3.906442403793335
# Epoch # 1, Time Step # 147, Loss Value = 4.483826637268066
# Epoch # 1, Time Step # 148, Loss Value = 4.289120197296143
# Epoch # 1, Time Step # 149, Loss Value = 4.487117290496826
# Epoch # 1, Time Step # 150, Loss Value = 4.272083282470703
# Epoch # 1, Time Step # 151, Loss Value = 4.329189300537109
# Epoch # 1, Time Step # 152, Loss Value = 4.553346633911133
# Epoch # 1, Time Step # 153, Loss Value = 4.206209659576416
# Epoch # 1, Time Step # 154, Loss Value = 4.16020393371582
# Epoch # 1, Time Step # 155, Loss Value = 4.40312385559082
# Epoch # 1, Time Step # 156, Loss Value = 4.360952854156494
# Epoch # 1, Time Step # 157, Loss Value = 4.390326499938965
# Epoch # 1, Time Step # 158, Loss Value = 4.35060453414917
# Epoch # 1, Time Step # 159, Loss Value = 5.318171501159668
# Epoch # 1, Time Step # 160, Loss Value = 5.0462517738342285
# Epoch # 1, Time Step # 161, Loss Value = 5.359203338623047
# Epoch # 1, Time Step # 162, Loss Value = 5.183371067047119
# Epoch # 1, Time Step # 163, Loss Value = 4.862486362457275
# Epoch # 1, Time Step # 164, Loss Value = 4.88521146774292
# Epoch # 1, Time Step # 165, Loss Value = 4.6134538650512695
# Epoch # 1, Time Step # 166, Loss Value = 4.447741985321045
# Epoch # 1, Time Step # 167, Loss Value = 4.9334635734558105
# Epoch # 1, Time Step # 168, Loss Value = 4.679488658905029
# Epoch # 1, Time Step # 169, Loss Value = 4.6813554763793945
# Epoch # 1, Time Step # 170, Loss Value = 4.78495454788208
# Epoch # 1, Time Step # 171, Loss Value = 4.823580265045166
# Epoch # 1, Time Step # 172, Loss Value = 5.248219966888428
# Epoch # 1, Time Step # 173, Loss Value = 4.9321393966674805
# Epoch # 1, Time Step # 174, Loss Value = 5.091490268707275
# Epoch # 1, Time Step # 175, Loss Value = 4.522663116455078
# Epoch # 1, Time Step # 176, Loss Value = 4.385281562805176
# Epoch # 1, Time Step # 177, Loss Value = 4.4603271484375
# Epoch # 1, Time Step # 178, Loss Value = 4.694299697875977
# Epoch # 1, Time Step # 179, Loss Value = 4.479970932006836
# Epoch # 1, Time Step # 180, Loss Value = 4.713424205780029
# Epoch # 1, Time Step # 181, Loss Value = 4.471969127655029
# Epoch # 1, Time Step # 182, Loss Value = 4.2996931076049805
# Epoch # 1, Time Step # 183, Loss Value = 4.408512592315674
# Epoch # 1, Time Step # 184, Loss Value = 4.4674787521362305
# Epoch # 1, Time Step # 185, Loss Value = 4.401449680328369
# Epoch # 1, Time Step # 186, Loss Value = 4.529068470001221
# Epoch # 1, Time Step # 187, Loss Value = 5.5356125831604
# Epoch # 1, Time Step # 188, Loss Value = 4.454787254333496
# Epoch # 1, Time Step # 189, Loss Value = 4.509896755218506
# Epoch # 1, Time Step # 190, Loss Value = 4.418086051940918
# Epoch # 1, Time Step # 191, Loss Value = 4.4578022956848145
# Epoch # 1, Time Step # 192, Loss Value = 4.562188625335693
# Epoch # 1, Time Step # 193, Loss Value = 4.170313835144043
# Epoch # 1, Time Step # 194, Loss Value = 4.4846673011779785
# Epoch # 1, Time Step # 195, Loss Value = 4.735605239868164
# Epoch # 1, Time Step # 196, Loss Value = 4.793231964111328
# Epoch # 1, Time Step # 197, Loss Value = 4.656627655029297
# Epoch # 1, Time Step # 198, Loss Value = 4.601354122161865
# Epoch # 1, Time Step # 199, Loss Value = 4.626449108123779
# Epoch # 2, Time Step # 0, Loss Value = 4.5339179039001465
# Epoch # 2, Time Step # 1, Loss Value = 4.880251884460449
# Epoch # 2, Time Step # 2, Loss Value = 4.808570861816406
# Epoch # 2, Time Step # 3, Loss Value = 5.283659934997559
# Epoch # 2, Time Step # 4, Loss Value = 5.313765048980713
# Epoch # 2, Time Step # 5, Loss Value = 4.973106384277344
# Epoch # 2, Time Step # 6, Loss Value = 5.207180500030518
# Epoch # 2, Time Step # 7, Loss Value = 5.100485801696777
# Epoch # 2, Time Step # 8, Loss Value = 5.2804083824157715
# Epoch # 2, Time Step # 9, Loss Value = 5.310732364654541
# Epoch # 2, Time Step # 10, Loss Value = 4.8755083084106445
# Epoch # 2, Time Step # 11, Loss Value = 5.197441577911377
# Epoch # 2, Time Step # 12, Loss Value = 4.807618618011475
# Epoch # 2, Time Step # 13, Loss Value = 5.337421417236328
# Epoch # 2, Time Step # 14, Loss Value = 5.17219352722168
# Epoch # 2, Time Step # 15, Loss Value = 5.180680751800537
# Epoch # 2, Time Step # 16, Loss Value = 4.916281700134277
# Epoch # 2, Time Step # 17, Loss Value = 5.097240924835205
# Epoch # 2, Time Step # 18, Loss Value = 4.878056049346924
# Epoch # 2, Time Step # 19, Loss Value = 5.16562032699585
# Epoch # 2, Time Step # 20, Loss Value = 5.049002170562744
# Epoch # 2, Time Step # 21, Loss Value = 4.8603835105896
# Epoch # 2, Time Step # 22, Loss Value = 4.608402729034424
# Epoch # 2, Time Step # 23, Loss Value = 4.919749736785889
# Epoch # 2, Time Step # 24, Loss Value = 5.271877288818359
# Epoch # 2, Time Step # 25, Loss Value = 5.031454563140869
# Epoch # 2, Time Step # 26, Loss Value = 4.969899654388428
# Epoch # 2, Time Step # 27, Loss Value = 5.038203239440918
# Epoch # 2, Time Step # 28, Loss Value = 4.820050239562988
# Epoch # 2, Time Step # 29, Loss Value = 4.839567184448242
# Epoch # 2, Time Step # 30, Loss Value = 4.682806968688965
# Epoch # 2, Time Step # 31, Loss Value = 4.641044616699219
# Epoch # 2, Time Step # 32, Loss Value = 4.629737377166748
# Epoch # 2, Time Step # 33, Loss Value = 4.710239887237549
# Epoch # 2, Time Step # 34, Loss Value = 5.037055969238281
# Epoch # 2, Time Step # 35, Loss Value = 5.204585552215576
# Epoch # 2, Time Step # 36, Loss Value = 5.285698890686035
# Epoch # 2, Time Step # 37, Loss Value = 5.171304702758789
# Epoch # 2, Time Step # 38, Loss Value = 5.12187385559082
# Epoch # 2, Time Step # 39, Loss Value = 5.1758294105529785
# Epoch # 2, Time Step # 40, Loss Value = 4.920806884765625
# Epoch # 2, Time Step # 41, Loss Value = 5.024759769439697
# Epoch # 2, Time Step # 42, Loss Value = 4.677312850952148
# Epoch # 2, Time Step # 43, Loss Value = 4.948925971984863
# Epoch # 2, Time Step # 44, Loss Value = 4.655149936676025
# Epoch # 2, Time Step # 45, Loss Value = 4.7335004806518555
# Epoch # 2, Time Step # 46, Loss Value = 4.982300281524658
# Epoch # 2, Time Step # 47, Loss Value = 4.595127105712891
# Epoch # 2, Time Step # 48, Loss Value = 4.850935459136963
# Epoch # 2, Time Step # 49, Loss Value = 4.739102363586426
# Epoch # 2, Time Step # 50, Loss Value = 4.669034957885742
# Epoch # 2, Time Step # 51, Loss Value = 4.854519367218018
# Epoch # 2, Time Step # 52, Loss Value = 5.047942638397217
# Epoch # 2, Time Step # 53, Loss Value = 4.833168029785156
# Epoch # 2, Time Step # 54, Loss Value = 5.059703826904297
# Epoch # 2, Time Step # 55, Loss Value = 5.083990573883057
# Epoch # 2, Time Step # 56, Loss Value = 4.622945785522461
# Epoch # 2, Time Step # 57, Loss Value = 4.866383075714111
# Epoch # 2, Time Step # 58, Loss Value = 4.829383850097656
# Epoch # 2, Time Step # 59, Loss Value = 4.350804328918457
# Epoch # 2, Time Step # 60, Loss Value = 4.357393741607666
# Epoch # 2, Time Step # 61, Loss Value = 4.528223514556885
# Epoch # 2, Time Step # 62, Loss Value = 5.0267333984375
# Epoch # 2, Time Step # 63, Loss Value = 5.203440189361572
# Epoch # 2, Time Step # 64, Loss Value = 4.642546653747559
# Epoch # 2, Time Step # 65, Loss Value = 4.898719310760498
# Epoch # 2, Time Step # 66, Loss Value = 5.1785478591918945
# Epoch # 2, Time Step # 67, Loss Value = 5.440830230712891
# Epoch # 2, Time Step # 68, Loss Value = 4.827274799346924
# Epoch # 2, Time Step # 69, Loss Value = 5.505815029144287
# Epoch # 2, Time Step # 70, Loss Value = 4.851755619049072
# Epoch # 2, Time Step # 71, Loss Value = 4.786865711212158
# Epoch # 2, Time Step # 72, Loss Value = 4.608296871185303
# Epoch # 2, Time Step # 73, Loss Value = 5.105883598327637
# Epoch # 2, Time Step # 74, Loss Value = 4.926591396331787
# Epoch # 2, Time Step # 75, Loss Value = 4.8824005126953125
# Epoch # 2, Time Step # 76, Loss Value = 4.9662184715271
# Epoch # 2, Time Step # 77, Loss Value = 4.829318523406982
# Epoch # 2, Time Step # 78, Loss Value = 4.458718299865723
# Epoch # 2, Time Step # 79, Loss Value = 4.8853631019592285
# Epoch # 2, Time Step # 80, Loss Value = 4.151248931884766
# Epoch # 2, Time Step # 81, Loss Value = 4.625045299530029
# Epoch # 2, Time Step # 82, Loss Value = 4.291146755218506
# Epoch # 2, Time Step # 83, Loss Value = 4.500462532043457
# Epoch # 2, Time Step # 84, Loss Value = 4.232047080993652
# Epoch # 2, Time Step # 85, Loss Value = 4.320505142211914
# Epoch # 2, Time Step # 86, Loss Value = 3.9682884216308594
# Epoch # 2, Time Step # 87, Loss Value = 4.134446620941162
# Epoch # 2, Time Step # 88, Loss Value = 4.33126163482666
# Epoch # 2, Time Step # 89, Loss Value = 4.138332366943359
# Epoch # 2, Time Step # 90, Loss Value = 3.4288811683654785
# Epoch # 2, Time Step # 91, Loss Value = 3.9391305446624756
# Epoch # 2, Time Step # 92, Loss Value = 4.882473468780518
# Epoch # 2, Time Step # 93, Loss Value = 3.7871625423431396
# Epoch # 2, Time Step # 94, Loss Value = 4.843984603881836
# Epoch # 2, Time Step # 95, Loss Value = 6.036600112915039
# Epoch # 2, Time Step # 96, Loss Value = 6.221277713775635
# Epoch # 2, Time Step # 97, Loss Value = 4.8179168701171875
# Epoch # 2, Time Step # 98, Loss Value = 4.181851387023926
# Epoch # 2, Time Step # 99, Loss Value = 4.342221260070801
# Epoch # 2, Time Step # 100, Loss Value = 4.5470709800720215
# Epoch # 2, Time Step # 101, Loss Value = 3.817906141281128
# Epoch # 2, Time Step # 102, Loss Value = 3.677860736846924
# Epoch # 2, Time Step # 103, Loss Value = 4.2593607902526855
# Epoch # 2, Time Step # 104, Loss Value = 4.124941349029541
# Epoch # 2, Time Step # 105, Loss Value = 4.158454418182373
# Epoch # 2, Time Step # 106, Loss Value = 4.049689292907715
# Epoch # 2, Time Step # 107, Loss Value = 3.757624864578247
# Epoch # 2, Time Step # 108, Loss Value = 4.077844142913818
# Epoch # 2, Time Step # 109, Loss Value = 3.8161351680755615
# Epoch # 2, Time Step # 110, Loss Value = 3.9327728748321533
# Epoch # 2, Time Step # 111, Loss Value = 5.051248550415039
# Epoch # 2, Time Step # 112, Loss Value = 5.436234474182129
# Epoch # 2, Time Step # 113, Loss Value = 4.867152690887451
# Epoch # 2, Time Step # 114, Loss Value = 4.36863374710083
# Epoch # 2, Time Step # 115, Loss Value = 4.366203784942627
# Epoch # 2, Time Step # 116, Loss Value = 4.494523525238037
# Epoch # 2, Time Step # 117, Loss Value = 4.3361592292785645
# Epoch # 2, Time Step # 118, Loss Value = 4.147150039672852
# Epoch # 2, Time Step # 119, Loss Value = 4.5388665199279785
# Epoch # 2, Time Step # 120, Loss Value = 4.981408596038818
# Epoch # 2, Time Step # 121, Loss Value = 3.92702579498291
# Epoch # 2, Time Step # 122, Loss Value = 4.250577926635742
# Epoch # 2, Time Step # 123, Loss Value = 4.22245454788208
# Epoch # 2, Time Step # 124, Loss Value = 4.081707954406738
# Epoch # 2, Time Step # 125, Loss Value = 4.204991817474365
# Epoch # 2, Time Step # 126, Loss Value = 4.1145429611206055
# Epoch # 2, Time Step # 127, Loss Value = 4.175118923187256
# Epoch # 2, Time Step # 128, Loss Value = 4.759392261505127
# Epoch # 2, Time Step # 129, Loss Value = 4.93228816986084
# Epoch # 2, Time Step # 130, Loss Value = 4.92277717590332
# Epoch # 2, Time Step # 131, Loss Value = 4.304118633270264
# Epoch # 2, Time Step # 132, Loss Value = 3.972735643386841
# Epoch # 2, Time Step # 133, Loss Value = 3.775696277618408
# Epoch # 2, Time Step # 134, Loss Value = 4.241833686828613
# Epoch # 2, Time Step # 135, Loss Value = 3.925929307937622
# Epoch # 2, Time Step # 136, Loss Value = 4.207884788513184
# Epoch # 2, Time Step # 137, Loss Value = 4.3050336837768555
# Epoch # 2, Time Step # 138, Loss Value = 3.936307191848755
# Epoch # 2, Time Step # 139, Loss Value = 4.485455513000488
# Epoch # 2, Time Step # 140, Loss Value = 4.278522968292236
# Epoch # 2, Time Step # 141, Loss Value = 3.97320818901062
# Epoch # 2, Time Step # 142, Loss Value = 3.806731939315796
# Epoch # 2, Time Step # 143, Loss Value = 4.1756134033203125
# Epoch # 2, Time Step # 144, Loss Value = 3.8702316284179688
# Epoch # 2, Time Step # 145, Loss Value = 3.752902030944824
# Epoch # 2, Time Step # 146, Loss Value = 3.678356409072876
# Epoch # 2, Time Step # 147, Loss Value = 4.2369303703308105
# Epoch # 2, Time Step # 148, Loss Value = 4.039862632751465
# Epoch # 2, Time Step # 149, Loss Value = 4.242507457733154
# Epoch # 2, Time Step # 150, Loss Value = 4.015307903289795
# Epoch # 2, Time Step # 151, Loss Value = 4.028234958648682
# Epoch # 2, Time Step # 152, Loss Value = 4.284152030944824
# Epoch # 2, Time Step # 153, Loss Value = 3.9473512172698975
# Epoch # 2, Time Step # 154, Loss Value = 3.9345927238464355
# Epoch # 2, Time Step # 155, Loss Value = 4.191905975341797
# Epoch # 2, Time Step # 156, Loss Value = 4.12797212600708
# Epoch # 2, Time Step # 157, Loss Value = 4.169717311859131
# Epoch # 2, Time Step # 158, Loss Value = 4.119758605957031
# Epoch # 2, Time Step # 159, Loss Value = 5.087881088256836
# Epoch # 2, Time Step # 160, Loss Value = 4.805870056152344
# Epoch # 2, Time Step # 161, Loss Value = 5.091588020324707
# Epoch # 2, Time Step # 162, Loss Value = 4.838339805603027
# Epoch # 2, Time Step # 163, Loss Value = 4.641820430755615
# Epoch # 2, Time Step # 164, Loss Value = 4.628668785095215
# Epoch # 2, Time Step # 165, Loss Value = 4.3560309410095215
# Epoch # 2, Time Step # 166, Loss Value = 4.173305988311768
# Epoch # 2, Time Step # 167, Loss Value = 4.681143283843994
# Epoch # 2, Time Step # 168, Loss Value = 4.480423927307129
# Epoch # 2, Time Step # 169, Loss Value = 4.409163475036621
# Epoch # 2, Time Step # 170, Loss Value = 4.5514607429504395
# Epoch # 2, Time Step # 171, Loss Value = 4.549154758453369
# Epoch # 2, Time Step # 172, Loss Value = 5.016019344329834
# Epoch # 2, Time Step # 173, Loss Value = 4.675282955169678
# Epoch # 2, Time Step # 174, Loss Value = 4.84592342376709
# Epoch # 2, Time Step # 175, Loss Value = 4.240543365478516
# Epoch # 2, Time Step # 176, Loss Value = 4.153674602508545
# Epoch # 2, Time Step # 177, Loss Value = 4.203984260559082
# Epoch # 2, Time Step # 178, Loss Value = 4.407240867614746
# Epoch # 2, Time Step # 179, Loss Value = 4.204885005950928
# Epoch # 2, Time Step # 180, Loss Value = 4.35590124130249
# Epoch # 2, Time Step # 181, Loss Value = 4.187450885772705
# Epoch # 2, Time Step # 182, Loss Value = 4.038046836853027
# Epoch # 2, Time Step # 183, Loss Value = 4.198733329772949
# Epoch # 2, Time Step # 184, Loss Value = 4.211175441741943
# Epoch # 2, Time Step # 185, Loss Value = 4.128058910369873
# Epoch # 2, Time Step # 186, Loss Value = 4.243598461151123
# Epoch # 2, Time Step # 187, Loss Value = 5.289337158203125
# Epoch # 2, Time Step # 188, Loss Value = 4.226524353027344
# Epoch # 2, Time Step # 189, Loss Value = 4.274354934692383
# Epoch # 2, Time Step # 190, Loss Value = 4.1584014892578125
# Epoch # 2, Time Step # 191, Loss Value = 4.233489990234375
# Epoch # 2, Time Step # 192, Loss Value = 4.27699089050293
# Epoch # 2, Time Step # 193, Loss Value = 3.930145502090454
# Epoch # 2, Time Step # 194, Loss Value = 4.240660190582275
# Epoch # 2, Time Step # 195, Loss Value = 4.526193141937256
# Epoch # 2, Time Step # 196, Loss Value = 4.5441813468933105
# Epoch # 2, Time Step # 197, Loss Value = 4.452507972717285
# Epoch # 2, Time Step # 198, Loss Value = 4.3667426109313965
# Epoch # 2, Time Step # 199, Loss Value = 4.408771991729736
# Epoch # 3, Time Step # 0, Loss Value = 4.336898326873779
# Epoch # 3, Time Step # 1, Loss Value = 4.6672797203063965
# Epoch # 3, Time Step # 2, Loss Value = 4.593521595001221
# Epoch # 3, Time Step # 3, Loss Value = 5.073498725891113
# Epoch # 3, Time Step # 4, Loss Value = 5.096611499786377
# Epoch # 3, Time Step # 5, Loss Value = 4.733916282653809
# Epoch # 3, Time Step # 6, Loss Value = 5.002906799316406
# Epoch # 3, Time Step # 7, Loss Value = 4.871520519256592
# Epoch # 3, Time Step # 8, Loss Value = 5.085464954376221
# Epoch # 3, Time Step # 9, Loss Value = 5.121092796325684
# Epoch # 3, Time Step # 10, Loss Value = 4.645207405090332
# Epoch # 3, Time Step # 11, Loss Value = 4.99716854095459
# Epoch # 3, Time Step # 12, Loss Value = 4.602838039398193
# Epoch # 3, Time Step # 13, Loss Value = 5.143983840942383
# Epoch # 3, Time Step # 14, Loss Value = 4.97133731842041
# Epoch # 3, Time Step # 15, Loss Value = 4.976891040802002
# Epoch # 3, Time Step # 16, Loss Value = 4.714890003204346
# Epoch # 3, Time Step # 17, Loss Value = 4.904077529907227
# Epoch # 3, Time Step # 18, Loss Value = 4.708841323852539
# Epoch # 3, Time Step # 19, Loss Value = 4.978439807891846
# Epoch # 3, Time Step # 20, Loss Value = 4.8321027755737305
# Epoch # 3, Time Step # 21, Loss Value = 4.672365188598633
# Epoch # 3, Time Step # 22, Loss Value = 4.372344493865967
# Epoch # 3, Time Step # 23, Loss Value = 4.676425933837891
# Epoch # 3, Time Step # 24, Loss Value = 5.068795204162598
# Epoch # 3, Time Step # 25, Loss Value = 4.841495513916016
# Epoch # 3, Time Step # 26, Loss Value = 4.802114963531494
# Epoch # 3, Time Step # 27, Loss Value = 4.821895122528076
# Epoch # 3, Time Step # 28, Loss Value = 4.595948696136475
# Epoch # 3, Time Step # 29, Loss Value = 4.638576507568359
# Epoch # 3, Time Step # 30, Loss Value = 4.482602596282959
# Epoch # 3, Time Step # 31, Loss Value = 4.405216217041016
# Epoch # 3, Time Step # 32, Loss Value = 4.425402641296387
# Epoch # 3, Time Step # 33, Loss Value = 4.505127906799316
# Epoch # 3, Time Step # 34, Loss Value = 4.849449157714844
# Epoch # 3, Time Step # 35, Loss Value = 4.992354869842529
# Epoch # 3, Time Step # 36, Loss Value = 5.1002349853515625
# Epoch # 3, Time Step # 37, Loss Value = 4.966248035430908
# Epoch # 3, Time Step # 38, Loss Value = 4.924686908721924
# Epoch # 3, Time Step # 39, Loss Value = 4.987504959106445
# Epoch # 3, Time Step # 40, Loss Value = 4.747054100036621
# Epoch # 3, Time Step # 41, Loss Value = 4.842159748077393
# Epoch # 3, Time Step # 42, Loss Value = 4.508692741394043
# Epoch # 3, Time Step # 43, Loss Value = 4.777168273925781
# Epoch # 3, Time Step # 44, Loss Value = 4.44322395324707
# Epoch # 3, Time Step # 45, Loss Value = 4.536121845245361
# Epoch # 3, Time Step # 46, Loss Value = 4.788957595825195
# Epoch # 3, Time Step # 47, Loss Value = 4.382081985473633
# Epoch # 3, Time Step # 48, Loss Value = 4.6511430740356445
# Epoch # 3, Time Step # 49, Loss Value = 4.564072132110596
# Epoch # 3, Time Step # 50, Loss Value = 4.485320568084717
# Epoch # 3, Time Step # 51, Loss Value = 4.667449951171875
# Epoch # 3, Time Step # 52, Loss Value = 4.862152099609375
# Epoch # 3, Time Step # 53, Loss Value = 4.615219593048096
# Epoch # 3, Time Step # 54, Loss Value = 4.849104404449463
# Epoch # 3, Time Step # 55, Loss Value = 4.8895463943481445
# Epoch # 3, Time Step # 56, Loss Value = 4.393686771392822
# Epoch # 3, Time Step # 57, Loss Value = 4.651565074920654
# Epoch # 3, Time Step # 58, Loss Value = 4.609159469604492
# Epoch # 3, Time Step # 59, Loss Value = 4.146443843841553
# Epoch # 3, Time Step # 60, Loss Value = 4.10444450378418
# Epoch # 3, Time Step # 61, Loss Value = 4.3250732421875
# Epoch # 3, Time Step # 62, Loss Value = 4.814102649688721
# Epoch # 3, Time Step # 63, Loss Value = 4.99124813079834
# Epoch # 3, Time Step # 64, Loss Value = 4.422665596008301
# Epoch # 3, Time Step # 65, Loss Value = 4.686267852783203
# Epoch # 3, Time Step # 66, Loss Value = 4.985856533050537
# Epoch # 3, Time Step # 67, Loss Value = 5.253904342651367
# Epoch # 3, Time Step # 68, Loss Value = 4.593959331512451
# Epoch # 3, Time Step # 69, Loss Value = 5.348038673400879
# Epoch # 3, Time Step # 70, Loss Value = 4.6394548416137695
# Epoch # 3, Time Step # 71, Loss Value = 4.575576305389404
# Epoch # 3, Time Step # 72, Loss Value = 4.371678352355957
# Epoch # 3, Time Step # 73, Loss Value = 4.895200252532959
# Epoch # 3, Time Step # 74, Loss Value = 4.701467990875244
# Epoch # 3, Time Step # 75, Loss Value = 4.669825553894043
# Epoch # 3, Time Step # 76, Loss Value = 4.750487804412842
# Epoch # 3, Time Step # 77, Loss Value = 4.599733829498291
# Epoch # 3, Time Step # 78, Loss Value = 4.229503631591797
# Epoch # 3, Time Step # 79, Loss Value = 4.650147438049316
# Epoch # 3, Time Step # 80, Loss Value = 3.9006834030151367
# Epoch # 3, Time Step # 81, Loss Value = 4.389791011810303
# Epoch # 3, Time Step # 82, Loss Value = 4.107977390289307
# Epoch # 3, Time Step # 83, Loss Value = 4.274728775024414
# Epoch # 3, Time Step # 84, Loss Value = 3.999330520629883
# Epoch # 3, Time Step # 85, Loss Value = 4.15102481842041
# Epoch # 3, Time Step # 86, Loss Value = 3.775247573852539
# Epoch # 3, Time Step # 87, Loss Value = 3.9581751823425293
# Epoch # 3, Time Step # 88, Loss Value = 4.156318187713623
# Epoch # 3, Time Step # 89, Loss Value = 3.9308106899261475
# Epoch # 3, Time Step # 90, Loss Value = 3.1877899169921875
# Epoch # 3, Time Step # 91, Loss Value = 3.7419588565826416
# Epoch # 3, Time Step # 92, Loss Value = 4.693327903747559
# Epoch # 3, Time Step # 93, Loss Value = 3.6162006855010986
# Epoch # 3, Time Step # 94, Loss Value = 4.649745941162109
# Epoch # 3, Time Step # 95, Loss Value = 5.8566789627075195
# Epoch # 3, Time Step # 96, Loss Value = 6.055442810058594
# Epoch # 3, Time Step # 97, Loss Value = 4.6033759117126465
# Epoch # 3, Time Step # 98, Loss Value = 3.9948651790618896
# Epoch # 3, Time Step # 99, Loss Value = 4.146414756774902
# Epoch # 3, Time Step # 100, Loss Value = 4.344634532928467
# Epoch # 3, Time Step # 101, Loss Value = 3.6411192417144775
# Epoch # 3, Time Step # 102, Loss Value = 3.4761903285980225
# Epoch # 3, Time Step # 103, Loss Value = 4.054206371307373
# Epoch # 3, Time Step # 104, Loss Value = 3.9055514335632324
# Epoch # 3, Time Step # 105, Loss Value = 3.991213321685791
# Epoch # 3, Time Step # 106, Loss Value = 3.8297836780548096
# Epoch # 3, Time Step # 107, Loss Value = 3.5924887657165527
# Epoch # 3, Time Step # 108, Loss Value = 3.935399293899536
# Epoch # 3, Time Step # 109, Loss Value = 3.682563304901123
# Epoch # 3, Time Step # 110, Loss Value = 3.748927354812622
# Epoch # 3, Time Step # 111, Loss Value = 4.840167045593262
# Epoch # 3, Time Step # 112, Loss Value = 5.214186191558838
# Epoch # 3, Time Step # 113, Loss Value = 4.655410289764404
# Epoch # 3, Time Step # 114, Loss Value = 4.137757301330566
# Epoch # 3, Time Step # 115, Loss Value = 4.168122291564941
# Epoch # 3, Time Step # 116, Loss Value = 4.217520713806152
# Epoch # 3, Time Step # 117, Loss Value = 4.133259296417236
# Epoch # 3, Time Step # 118, Loss Value = 3.949434518814087
# Epoch # 3, Time Step # 119, Loss Value = 4.332146167755127
# Epoch # 3, Time Step # 120, Loss Value = 4.755871772766113
# Epoch # 3, Time Step # 121, Loss Value = 3.722707986831665
# Epoch # 3, Time Step # 122, Loss Value = 4.055167198181152
# Epoch # 3, Time Step # 123, Loss Value = 4.004799842834473
# Epoch # 3, Time Step # 124, Loss Value = 3.887366771697998
# Epoch # 3, Time Step # 125, Loss Value = 4.015740871429443
# Epoch # 3, Time Step # 126, Loss Value = 3.883073568344116
# Epoch # 3, Time Step # 127, Loss Value = 3.9304070472717285
# Epoch # 3, Time Step # 128, Loss Value = 4.557784080505371
# Epoch # 3, Time Step # 129, Loss Value = 4.715220928192139
# Epoch # 3, Time Step # 130, Loss Value = 4.726681709289551
# Epoch # 3, Time Step # 131, Loss Value = 4.091251373291016
# Epoch # 3, Time Step # 132, Loss Value = 3.7844653129577637
# Epoch # 3, Time Step # 133, Loss Value = 3.61411714553833
# Epoch # 3, Time Step # 134, Loss Value = 4.023123741149902
# Epoch # 3, Time Step # 135, Loss Value = 3.70263671875
# Epoch # 3, Time Step # 136, Loss Value = 3.975423812866211
# Epoch # 3, Time Step # 137, Loss Value = 4.084046363830566
# Epoch # 3, Time Step # 138, Loss Value = 3.7589476108551025
# Epoch # 3, Time Step # 139, Loss Value = 4.277374744415283
# Epoch # 3, Time Step # 140, Loss Value = 4.063755512237549
# Epoch # 3, Time Step # 141, Loss Value = 3.7749791145324707
# Epoch # 3, Time Step # 142, Loss Value = 3.6015641689300537
# Epoch # 3, Time Step # 143, Loss Value = 3.9600210189819336
# Epoch # 3, Time Step # 144, Loss Value = 3.687072992324829
# Epoch # 3, Time Step # 145, Loss Value = 3.5247111320495605
# Epoch # 3, Time Step # 146, Loss Value = 3.473252296447754
# Epoch # 3, Time Step # 147, Loss Value = 4.033334732055664
# Epoch # 3, Time Step # 148, Loss Value = 3.834423303604126
# Epoch # 3, Time Step # 149, Loss Value = 4.038708686828613
# Epoch # 3, Time Step # 150, Loss Value = 3.772181987762451
# Epoch # 3, Time Step # 151, Loss Value = 3.7853450775146484
# Epoch # 3, Time Step # 152, Loss Value = 4.060464382171631
# Epoch # 3, Time Step # 153, Loss Value = 3.734787940979004
# Epoch # 3, Time Step # 154, Loss Value = 3.742345094680786
# Epoch # 3, Time Step # 155, Loss Value = 4.007752418518066
# Epoch # 3, Time Step # 156, Loss Value = 3.9521431922912598
# Epoch # 3, Time Step # 157, Loss Value = 3.962742805480957
# Epoch # 3, Time Step # 158, Loss Value = 3.9164156913757324
# Epoch # 3, Time Step # 159, Loss Value = 4.864996910095215
# Epoch # 3, Time Step # 160, Loss Value = 4.60518217086792
# Epoch # 3, Time Step # 161, Loss Value = 4.878917217254639
# Epoch # 3, Time Step # 162, Loss Value = 4.5867228507995605
# Epoch # 3, Time Step # 163, Loss Value = 4.455020904541016
# Epoch # 3, Time Step # 164, Loss Value = 4.423727989196777
# Epoch # 3, Time Step # 165, Loss Value = 4.128364562988281
# Epoch # 3, Time Step # 166, Loss Value = 3.9664268493652344
# Epoch # 3, Time Step # 167, Loss Value = 4.477469444274902
# Epoch # 3, Time Step # 168, Loss Value = 4.312374114990234
# Epoch # 3, Time Step # 169, Loss Value = 4.200283050537109
# Epoch # 3, Time Step # 170, Loss Value = 4.356018543243408
# Epoch # 3, Time Step # 171, Loss Value = 4.3231048583984375
# Epoch # 3, Time Step # 172, Loss Value = 4.813531875610352
# Epoch # 3, Time Step # 173, Loss Value = 4.4573974609375
# Epoch # 3, Time Step # 174, Loss Value = 4.647378921508789
# Epoch # 3, Time Step # 175, Loss Value = 3.997607707977295
# Epoch # 3, Time Step # 176, Loss Value = 3.95169997215271
# Epoch # 3, Time Step # 177, Loss Value = 3.984942674636841
# Epoch # 3, Time Step # 178, Loss Value = 4.169147968292236
# Epoch # 3, Time Step # 179, Loss Value = 3.987233877182007
# Epoch # 3, Time Step # 180, Loss Value = 4.082662105560303
# Epoch # 3, Time Step # 181, Loss Value = 3.9536261558532715
# Epoch # 3, Time Step # 182, Loss Value = 3.8122293949127197
# Epoch # 3, Time Step # 183, Loss Value = 4.011829853057861
# Epoch # 3, Time Step # 184, Loss Value = 4.006047248840332
# Epoch # 3, Time Step # 185, Loss Value = 3.904074192047119
# Epoch # 3, Time Step # 186, Loss Value = 4.021832466125488
# Epoch # 3, Time Step # 187, Loss Value = 5.055868625640869
# Epoch # 3, Time Step # 188, Loss Value = 4.028439998626709
# Epoch # 3, Time Step # 189, Loss Value = 4.068821430206299
# Epoch # 3, Time Step # 190, Loss Value = 3.9453659057617188
# Epoch # 3, Time Step # 191, Loss Value = 4.038311004638672
# Epoch # 3, Time Step # 192, Loss Value = 4.027900218963623
# Epoch # 3, Time Step # 193, Loss Value = 3.7408745288848877
# Epoch # 3, Time Step # 194, Loss Value = 4.027259826660156
# Epoch # 3, Time Step # 195, Loss Value = 4.35586404800415
# Epoch # 3, Time Step # 196, Loss Value = 4.350103855133057
# Epoch # 3, Time Step # 197, Loss Value = 4.28929328918457
# Epoch # 3, Time Step # 198, Loss Value = 4.198226451873779
# Epoch # 3, Time Step # 199, Loss Value = 4.231351852416992
# Epoch # 4, Time Step # 0, Loss Value = 4.167446613311768
# Epoch # 4, Time Step # 1, Loss Value = 4.484172344207764
# Epoch # 4, Time Step # 2, Loss Value = 4.3956618309021
# Epoch # 4, Time Step # 3, Loss Value = 4.875341415405273
# Epoch # 4, Time Step # 4, Loss Value = 4.896875381469727
# Epoch # 4, Time Step # 5, Loss Value = 4.5183844566345215
# Epoch # 4, Time Step # 6, Loss Value = 4.81754732131958
# Epoch # 4, Time Step # 7, Loss Value = 4.663130283355713
# Epoch # 4, Time Step # 8, Loss Value = 4.903160572052002
# Epoch # 4, Time Step # 9, Loss Value = 4.9424848556518555
# Epoch # 4, Time Step # 10, Loss Value = 4.446294784545898
# Epoch # 4, Time Step # 11, Loss Value = 4.818758010864258
# Epoch # 4, Time Step # 12, Loss Value = 4.420127868652344
# Epoch # 4, Time Step # 13, Loss Value = 4.959712505340576
# Epoch # 4, Time Step # 14, Loss Value = 4.788570404052734
# Epoch # 4, Time Step # 15, Loss Value = 4.800485610961914
# Epoch # 4, Time Step # 16, Loss Value = 4.540282249450684
# Epoch # 4, Time Step # 17, Loss Value = 4.712339878082275
# Epoch # 4, Time Step # 18, Loss Value = 4.549417018890381
# Epoch # 4, Time Step # 19, Loss Value = 4.799132347106934
# ...
# Epoch # 242, Time Step # 112, Loss Value = 0.13538600504398346
# Epoch # 242, Time Step # 113, Loss Value = 0.18404877185821533
# Epoch # 242, Time Step # 114, Loss Value = 0.1929677575826645
# Epoch # 242, Time Step # 115, Loss Value = 0.15462198853492737
# Epoch # 242, Time Step # 116, Loss Value = 0.16288800537586212
# Epoch # 242, Time Step # 117, Loss Value = 0.1863989681005478
# Epoch # 242, Time Step # 118, Loss Value = 0.19458827376365662
# Epoch # 242, Time Step # 119, Loss Value = 0.1639537811279297
# Epoch # 242, Time Step # 120, Loss Value = 0.1663532853126526
# Epoch # 242, Time Step # 121, Loss Value = 0.1724073886871338
# Epoch # 242, Time Step # 122, Loss Value = 0.2196243852376938
# Epoch # 242, Time Step # 123, Loss Value = 0.20996414124965668
# Epoch # 242, Time Step # 124, Loss Value = 0.2478383183479309
# Epoch # 242, Time Step # 125, Loss Value = 0.26073965430259705
# Epoch # 242, Time Step # 126, Loss Value = 0.17344972491264343
# Epoch # 242, Time Step # 127, Loss Value = 0.17711704969406128
# Epoch # 242, Time Step # 128, Loss Value = 0.1788080930709839
# Epoch # 242, Time Step # 129, Loss Value = 0.1601337045431137
# Epoch # 242, Time Step # 130, Loss Value = 0.1781255453824997
# Epoch # 242, Time Step # 131, Loss Value = 0.18200024962425232
# Epoch # 242, Time Step # 132, Loss Value = 0.1891828328371048
# Epoch # 242, Time Step # 133, Loss Value = 0.2512940466403961
# Epoch # 242, Time Step # 134, Loss Value = 0.19222815334796906
# Epoch # 242, Time Step # 135, Loss Value = 0.22189828753471375
# Epoch # 242, Time Step # 136, Loss Value = 0.20170767605304718
# Epoch # 242, Time Step # 137, Loss Value = 0.22493289411067963
# Epoch # 242, Time Step # 138, Loss Value = 0.28870120644569397
# Epoch # 242, Time Step # 139, Loss Value = 0.25256234407424927
# Epoch # 242, Time Step # 140, Loss Value = 0.2339998483657837
# Epoch # 242, Time Step # 141, Loss Value = 0.20981977880001068
# Epoch # 242, Time Step # 142, Loss Value = 0.1712116301059723
# Epoch # 242, Time Step # 143, Loss Value = 0.227203831076622
# Epoch # 242, Time Step # 144, Loss Value = 0.26305684447288513
# Epoch # 242, Time Step # 145, Loss Value = 0.17604871094226837
# Epoch # 242, Time Step # 146, Loss Value = 0.2881535589694977
# Epoch # 242, Time Step # 147, Loss Value = 0.24843338131904602
# Epoch # 242, Time Step # 148, Loss Value = 0.210703507065773
# Epoch # 242, Time Step # 149, Loss Value = 0.18282976746559143
# Epoch # 242, Time Step # 150, Loss Value = 0.1912466436624527
# Epoch # 242, Time Step # 151, Loss Value = 0.23749977350234985
# Epoch # 242, Time Step # 152, Loss Value = 0.22296841442584991
# Epoch # 242, Time Step # 153, Loss Value = 0.2558465600013733
# Epoch # 242, Time Step # 154, Loss Value = 0.21110853552818298
# Epoch # 242, Time Step # 155, Loss Value = 0.15569579601287842
# Epoch # 242, Time Step # 156, Loss Value = 0.24232694506645203
# Epoch # 242, Time Step # 157, Loss Value = 0.19599972665309906
# Epoch # 242, Time Step # 158, Loss Value = 0.20608623325824738
# Epoch # 242, Time Step # 159, Loss Value = 0.12539228796958923
# Epoch # 242, Time Step # 160, Loss Value = 0.18127675354480743
# Epoch # 242, Time Step # 161, Loss Value = 0.15563088655471802
# Epoch # 242, Time Step # 162, Loss Value = 0.12336651980876923
# Epoch # 242, Time Step # 163, Loss Value = 0.21589240431785583
# Epoch # 242, Time Step # 164, Loss Value = 0.2951008379459381
# Epoch # 242, Time Step # 165, Loss Value = 0.18810085952281952
# Epoch # 242, Time Step # 166, Loss Value = 0.17570050060749054
# Epoch # 242, Time Step # 167, Loss Value = 0.1707754284143448
# Epoch # 242, Time Step # 168, Loss Value = 0.13135269284248352
# Epoch # 242, Time Step # 169, Loss Value = 0.15193361043930054
# Epoch # 242, Time Step # 170, Loss Value = 0.16256162524223328
# Epoch # 242, Time Step # 171, Loss Value = 0.15948402881622314
# Epoch # 242, Time Step # 172, Loss Value = 0.178050234913826
# Epoch # 242, Time Step # 173, Loss Value = 0.18807367980480194
# Epoch # 242, Time Step # 174, Loss Value = 0.2203909158706665
# Epoch # 242, Time Step # 175, Loss Value = 0.19186216592788696
# Epoch # 242, Time Step # 176, Loss Value = 0.1734583079814911
# Epoch # 242, Time Step # 177, Loss Value = 0.20354409515857697
# Epoch # 242, Time Step # 178, Loss Value = 0.15660330653190613
# Epoch # 242, Time Step # 179, Loss Value = 0.14654861390590668
# Epoch # 242, Time Step # 180, Loss Value = 0.13314726948738098
# Epoch # 242, Time Step # 181, Loss Value = 0.21365077793598175
# Epoch # 242, Time Step # 182, Loss Value = 0.2244316190481186
# Epoch # 242, Time Step # 183, Loss Value = 0.19627848267555237
# Epoch # 242, Time Step # 184, Loss Value = 0.17293593287467957
# Epoch # 242, Time Step # 185, Loss Value = 0.22250978648662567
# Epoch # 242, Time Step # 186, Loss Value = 0.1576780378818512
# Epoch # 242, Time Step # 187, Loss Value = 0.14798110723495483
# Epoch # 242, Time Step # 188, Loss Value = 0.17687810957431793
# Epoch # 242, Time Step # 189, Loss Value = 0.20615477859973907
# Epoch # 242, Time Step # 190, Loss Value = 0.22851046919822693
# Epoch # 242, Time Step # 191, Loss Value = 0.20075565576553345
# Epoch # 242, Time Step # 192, Loss Value = 0.2349453717470169
# Epoch # 242, Time Step # 193, Loss Value = 0.18572679162025452
# Epoch # 242, Time Step # 194, Loss Value = 0.19032101333141327
# Epoch # 242, Time Step # 195, Loss Value = 0.1816634237766266
# Epoch # 242, Time Step # 196, Loss Value = 0.17471209168434143
# Epoch # 242, Time Step # 197, Loss Value = 0.19184906780719757
# Epoch # 242, Time Step # 198, Loss Value = 0.15182313323020935
# Epoch # 242, Time Step # 199, Loss Value = 0.26167652010917664
# Epoch # 243, Time Step # 0, Loss Value = 0.23508182168006897
# Epoch # 243, Time Step # 1, Loss Value = 0.2096770852804184
# Epoch # 243, Time Step # 2, Loss Value = 0.19898533821105957
# Epoch # 243, Time Step # 3, Loss Value = 0.1471259444952011
# Epoch # 243, Time Step # 4, Loss Value = 0.14906471967697144
# Epoch # 243, Time Step # 5, Loss Value = 0.19260139763355255
# Epoch # 243, Time Step # 6, Loss Value = 0.20955465734004974
# Epoch # 243, Time Step # 7, Loss Value = 0.14580847322940826
# Epoch # 243, Time Step # 8, Loss Value = 0.23454125225543976
# Epoch # 243, Time Step # 9, Loss Value = 0.16754977405071259
# Epoch # 243, Time Step # 10, Loss Value = 0.23912641406059265
# Epoch # 243, Time Step # 11, Loss Value = 0.20206692814826965
# Epoch # 243, Time Step # 12, Loss Value = 0.18604934215545654
# Epoch # 243, Time Step # 13, Loss Value = 0.17904110252857208
# Epoch # 243, Time Step # 14, Loss Value = 0.15349073708057404
# Epoch # 243, Time Step # 15, Loss Value = 0.22290156781673431
# Epoch # 243, Time Step # 16, Loss Value = 0.21182790398597717
# Epoch # 243, Time Step # 17, Loss Value = 0.22458133101463318
# Epoch # 243, Time Step # 18, Loss Value = 0.1668473333120346
# Epoch # 243, Time Step # 19, Loss Value = 0.15890619158744812
# Epoch # 243, Time Step # 20, Loss Value = 0.19130191206932068
# Epoch # 243, Time Step # 21, Loss Value = 0.16572172939777374
# Epoch # 243, Time Step # 22, Loss Value = 0.24519893527030945
# Epoch # 243, Time Step # 23, Loss Value = 0.2220441848039627
# Epoch # 243, Time Step # 24, Loss Value = 0.19111154973506927
# Epoch # 243, Time Step # 25, Loss Value = 0.2382124960422516
# Epoch # 243, Time Step # 26, Loss Value = 0.219070166349411
# Epoch # 243, Time Step # 27, Loss Value = 0.21339549124240875
# Epoch # 243, Time Step # 28, Loss Value = 0.18260595202445984
# Epoch # 243, Time Step # 29, Loss Value = 0.20023636519908905
# Epoch # 243, Time Step # 30, Loss Value = 0.1936195194721222
# Epoch # 243, Time Step # 31, Loss Value = 0.23085491359233856
# Epoch # 243, Time Step # 32, Loss Value = 0.17956462502479553
# Epoch # 243, Time Step # 33, Loss Value = 0.2338898628950119
# Epoch # 243, Time Step # 34, Loss Value = 0.18717549741268158
# Epoch # 243, Time Step # 35, Loss Value = 0.15559501945972443
# Epoch # 243, Time Step # 36, Loss Value = 0.15093857049942017
# Epoch # 243, Time Step # 37, Loss Value = 0.16941334307193756
# Epoch # 243, Time Step # 38, Loss Value = 0.15099790692329407
# Epoch # 243, Time Step # 39, Loss Value = 0.14848697185516357
# Epoch # 243, Time Step # 40, Loss Value = 0.1822439730167389
# Epoch # 243, Time Step # 41, Loss Value = 0.2010040432214737
# Epoch # 243, Time Step # 42, Loss Value = 0.16937598586082458
# Epoch # 243, Time Step # 43, Loss Value = 0.15970079600811005
# Epoch # 243, Time Step # 44, Loss Value = 0.16668035089969635
# Epoch # 243, Time Step # 45, Loss Value = 0.1570431888103485
# Epoch # 243, Time Step # 46, Loss Value = 0.12907268106937408
# Epoch # 243, Time Step # 47, Loss Value = 0.15667495131492615
# Epoch # 243, Time Step # 48, Loss Value = 0.16320186853408813
# Epoch # 243, Time Step # 49, Loss Value = 0.22716063261032104
# Epoch # 243, Time Step # 50, Loss Value = 0.20754443109035492
# Epoch # 243, Time Step # 51, Loss Value = 0.13543960452079773
# Epoch # 243, Time Step # 52, Loss Value = 0.17682088911533356
# Epoch # 243, Time Step # 53, Loss Value = 0.21222181618213654
# Epoch # 243, Time Step # 54, Loss Value = 0.19013388454914093
# Epoch # 243, Time Step # 55, Loss Value = 0.2027771919965744
# Epoch # 243, Time Step # 56, Loss Value = 0.16396944224834442
# Epoch # 243, Time Step # 57, Loss Value = 0.17113618552684784
# Epoch # 243, Time Step # 58, Loss Value = 0.15163612365722656
# Epoch # 243, Time Step # 59, Loss Value = 0.17530624568462372
# Epoch # 243, Time Step # 60, Loss Value = 0.19436761736869812
# Epoch # 243, Time Step # 61, Loss Value = 0.18635113537311554
# Epoch # 243, Time Step # 62, Loss Value = 0.14772151410579681
# Epoch # 243, Time Step # 63, Loss Value = 0.1208530142903328
# Epoch # 243, Time Step # 64, Loss Value = 0.1689516007900238
# Epoch # 243, Time Step # 65, Loss Value = 0.17840881645679474
# Epoch # 243, Time Step # 66, Loss Value = 0.13224181532859802
# Epoch # 243, Time Step # 67, Loss Value = 0.11282951384782791
# Epoch # 243, Time Step # 68, Loss Value = 0.18710173666477203
# Epoch # 243, Time Step # 69, Loss Value = 0.1766539067029953
# Epoch # 243, Time Step # 70, Loss Value = 0.19608399271965027
# Epoch # 243, Time Step # 71, Loss Value = 0.2151009738445282
# Epoch # 243, Time Step # 72, Loss Value = 0.18868416547775269
# Epoch # 243, Time Step # 73, Loss Value = 0.15503321588039398
# Epoch # 243, Time Step # 74, Loss Value = 0.16624175012111664
# Epoch # 243, Time Step # 75, Loss Value = 0.17292967438697815
# Epoch # 243, Time Step # 76, Loss Value = 0.18107587099075317
# Epoch # 243, Time Step # 77, Loss Value = 0.18060491979122162
# Epoch # 243, Time Step # 78, Loss Value = 0.1870889812707901
# Epoch # 243, Time Step # 79, Loss Value = 0.1318870335817337
# Epoch # 243, Time Step # 80, Loss Value = 0.23891334235668182
# Epoch # 243, Time Step # 81, Loss Value = 0.23278184235095978
# Epoch # 243, Time Step # 82, Loss Value = 0.16597096621990204
# Epoch # 243, Time Step # 83, Loss Value = 0.256560355424881
# Epoch # 243, Time Step # 84, Loss Value = 0.22720010578632355
# Epoch # 243, Time Step # 85, Loss Value = 0.169563889503479
# Epoch # 243, Time Step # 86, Loss Value = 0.19346003234386444
# Epoch # 243, Time Step # 87, Loss Value = 0.22528709471225739
# Epoch # 243, Time Step # 88, Loss Value = 0.22296182811260223
# Epoch # 243, Time Step # 89, Loss Value = 0.22926566004753113
# Epoch # 243, Time Step # 90, Loss Value = 0.22414720058441162
# Epoch # 243, Time Step # 91, Loss Value = 0.2236219346523285
# Epoch # 243, Time Step # 92, Loss Value = 0.1663023680448532
# Epoch # 243, Time Step # 93, Loss Value = 0.21552522480487823
# Epoch # 243, Time Step # 94, Loss Value = 0.19880782067775726
# Epoch # 243, Time Step # 95, Loss Value = 0.13502608239650726
# Epoch # 243, Time Step # 96, Loss Value = 0.210211843252182
# Epoch # 243, Time Step # 97, Loss Value = 0.139952152967453
# Epoch # 243, Time Step # 98, Loss Value = 0.18536105751991272
# Epoch # 243, Time Step # 99, Loss Value = 0.20331989228725433
# Epoch # 243, Time Step # 100, Loss Value = 0.18061301112174988
# Epoch # 243, Time Step # 101, Loss Value = 0.1804610788822174
# Epoch # 243, Time Step # 102, Loss Value = 0.19754862785339355
# Epoch # 243, Time Step # 103, Loss Value = 0.22312527894973755
# Epoch # 243, Time Step # 104, Loss Value = 0.19523289799690247
# Epoch # 243, Time Step # 105, Loss Value = 0.21917036175727844
# Epoch # 243, Time Step # 106, Loss Value = 0.24873286485671997
# Epoch # 243, Time Step # 107, Loss Value = 0.20405295491218567
# Epoch # 243, Time Step # 108, Loss Value = 0.1724575161933899
# Epoch # 243, Time Step # 109, Loss Value = 0.19153310358524323
# Epoch # 243, Time Step # 110, Loss Value = 0.19953276216983795
# Epoch # 243, Time Step # 111, Loss Value = 0.15234890580177307
# Epoch # 243, Time Step # 112, Loss Value = 0.1293593794107437
# Epoch # 243, Time Step # 113, Loss Value = 0.17025165259838104
# Epoch # 243, Time Step # 114, Loss Value = 0.19462861120700836
# Epoch # 243, Time Step # 115, Loss Value = 0.16703830659389496
# Epoch # 243, Time Step # 116, Loss Value = 0.17274776101112366
# Epoch # 243, Time Step # 117, Loss Value = 0.1836099922657013
# Epoch # 243, Time Step # 118, Loss Value = 0.19664567708969116
# Epoch # 243, Time Step # 119, Loss Value = 0.15960554778575897
# Epoch # 243, Time Step # 120, Loss Value = 0.17352069914340973
# Epoch # 243, Time Step # 121, Loss Value = 0.1680627465248108
# Epoch # 243, Time Step # 122, Loss Value = 0.2167162001132965
# Epoch # 243, Time Step # 123, Loss Value = 0.2033384144306183
# Epoch # 243, Time Step # 124, Loss Value = 0.24621838331222534
# Epoch # 243, Time Step # 125, Loss Value = 0.25567224621772766
# Epoch # 243, Time Step # 126, Loss Value = 0.16535505652427673
# Epoch # 243, Time Step # 127, Loss Value = 0.17063525319099426
# Epoch # 243, Time Step # 128, Loss Value = 0.16232895851135254
# Epoch # 243, Time Step # 129, Loss Value = 0.16218595206737518
# Epoch # 243, Time Step # 130, Loss Value = 0.14854153990745544
# Epoch # 243, Time Step # 131, Loss Value = 0.18311148881912231
# Epoch # 243, Time Step # 132, Loss Value = 0.2034427970647812
# Epoch # 243, Time Step # 133, Loss Value = 0.25684285163879395
# Epoch # 243, Time Step # 134, Loss Value = 0.19828331470489502
# Epoch # 243, Time Step # 135, Loss Value = 0.21840868890285492
# Epoch # 243, Time Step # 136, Loss Value = 0.21764150261878967
# Epoch # 243, Time Step # 137, Loss Value = 0.22943396866321564
# Epoch # 243, Time Step # 138, Loss Value = 0.28931671380996704
# Epoch # 243, Time Step # 139, Loss Value = 0.24514326453208923
# Epoch # 243, Time Step # 140, Loss Value = 0.23475220799446106
# Epoch # 243, Time Step # 141, Loss Value = 0.21230652928352356
# Epoch # 243, Time Step # 142, Loss Value = 0.1902042031288147
# Epoch # 243, Time Step # 143, Loss Value = 0.22775815427303314
# Epoch # 243, Time Step # 144, Loss Value = 0.2565702199935913
# Epoch # 243, Time Step # 145, Loss Value = 0.17886348068714142
# Epoch # 243, Time Step # 146, Loss Value = 0.30554017424583435
# Epoch # 243, Time Step # 147, Loss Value = 0.25482091307640076
# Epoch # 243, Time Step # 148, Loss Value = 0.19941315054893494
# Epoch # 243, Time Step # 149, Loss Value = 0.19164836406707764
# Epoch # 243, Time Step # 150, Loss Value = 0.21063488721847534
# Epoch # 243, Time Step # 151, Loss Value = 0.23164628446102142
# Epoch # 243, Time Step # 152, Loss Value = 0.22085338830947876
# Epoch # 243, Time Step # 153, Loss Value = 0.22603707015514374
# Epoch # 243, Time Step # 154, Loss Value = 0.20597803592681885
# Epoch # 243, Time Step # 155, Loss Value = 0.15356327593326569
# Epoch # 243, Time Step # 156, Loss Value = 0.22838285565376282
# Epoch # 243, Time Step # 157, Loss Value = 0.2070210576057434
# Epoch # 243, Time Step # 158, Loss Value = 0.21065272390842438
# Epoch # 243, Time Step # 159, Loss Value = 0.1278892606496811
# Epoch # 243, Time Step # 160, Loss Value = 0.17525263130664825
# Epoch # 243, Time Step # 161, Loss Value = 0.151088684797287
# Epoch # 243, Time Step # 162, Loss Value = 0.11870517581701279
# Epoch # 243, Time Step # 163, Loss Value = 0.20694014430046082
# Epoch # 243, Time Step # 164, Loss Value = 0.31245237588882446
# Epoch # 243, Time Step # 165, Loss Value = 0.16341011226177216
# Epoch # 243, Time Step # 166, Loss Value = 0.17445261776447296
# Epoch # 243, Time Step # 167, Loss Value = 0.1690712720155716

# %%
torch.save(network.state_dict(),"model.pth")

# %%
def generate_translation(eng_sentence):

    tokenized_eng_sentence = src_sent_tokenizer.tokenize(eng_sentence)
    token_ids = src_sent_tokenizer.convert_tokens_to_ids(tokenized_eng_sentence)
    token_ids_tensor = torch.tensor(token_ids)
    token_ids_tensor = torch.unsqueeze(token_ids_tensor,0)

    if torch.cuda.is_available():
        device = torch.device("cuda")
        token_ids_tensor = token_ids_tensor.to(device)

    encoder_outputs,(final_encoder_output,final_candidate_cell_state) = network.encoder(token_ids_tensor)
    decoder_first_time_step_input = torch.tensor([[1]])

    if torch.cuda.is_available():
        encoder_outputs = encoder_outputs.to(device)
        final_encoder_output = final_encoder_output.to(device)
        final_candidate_cell_state = final_candidate_cell_state.to(device)
        decoder_first_time_step_input = decoder_first_time_step_input.to(device)

    decoder_first_time_step_output, (hidden_decoder_output, hidden_decoder_cell_state) = network.decoder(encoder_outputs,
                                                                          final_encoder_output,
                                                                          final_candidate_cell_state,
                                                                          decoder_first_time_step_input)

    generated_token_id = torch.argmax(F.softmax(decoder_first_time_step_output[:,0,:],dim=1),1)
    generated_token_id = torch.unsqueeze(generated_token_id,1)

    hindi_translated_sentence = str()
    hindi_translated_sentence += " " + hindi_idx2vocab[generated_token_id.item()]

    if torch.cuda.is_available():
        generated_token_id = generated_token_id.to(device)
        hidden_decoder_output = hidden_decoder_output.to(device)
        hidden_decoder_cell_state = hidden_decoder_cell_state.to(device)
        
    for i in range(Nd-1):
        
        decoder_first_time_step_output, (hidden_decoder_output, hidden_decoder_cell_state) = network.decoder(generated_token_id,
                                                                                                hidden_decoder_output,
                                                                                                hidden_decoder_cell_state)
        generated_token_id = torch.argmax(F.softmax(decoder_first_time_step_output[:,0,:],dim=1),1)
        generated_token_id = generated_token_id.unsqueeze(generated_token_id,1)

        if torch.cuda.is_available():
            generated_token_id = generated_token_id.to(device)
            hidden_decoder_output = hidden_decoder_output.to(device)
            hidden_decoder_cell_state = hidden_decoder_cell_state.to(device)

        if generated_token_id.item() == Vd["<EOS>"]:
            break

        hindi_translated_sentence += " " + hindi_idx2vocab[generated_token_id.item()]

    return hindi_translated_sentence

# %%
generate_translation("My name is Muriel")
